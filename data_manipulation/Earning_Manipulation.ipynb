# %% [markdown]
# ## Earnings

# %%
import pandas as pd

# %%
pharma=pd.read_csv('Pharma_Earning.csv')

# %%
pharma
# Out:
#      Rank            Category                   Company  Earnings      Country
# 0       1   💊 Pharmaceuticals         Johnson & Johnson  $24.43 B          USA
# 1       2   💊 Pharmaceuticals                     Roche  $17.67 B  Switzerland
# 2       3   💊 Pharmaceuticals                CVS Health  $14.09 B          USA
# 3       4   💊 Pharmaceuticals              Novo Nordisk  $12.84 B      Denmark
# 4       5   💊 Pharmaceuticals                    Pfizer  $12.25 B          USA
# ..    ...                 ...                       ...       ...          ...
# 691   693   💊 Pharmaceuticals                   BeiGene   -$1.3 B        China
# 692   694   💊 Pharmaceuticals                  Rite Aid   -$1.4 B          USA
# 693   695   💊 Pharmaceuticals                    Tilray  -$1.45 B       Canada
# 694   696   💊 Pharmaceuticals                   Moderna  -$2.67 B          USA
# 695   697   💊 Pharmaceuticals  Walgreens Boots Alliance  -$4.85 B          USA
#
# [696 rows x 5 columns]

# %%
food_category=[]
food_country=[]
food_earning=[]

# %%
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
# Set up the Chrome WebDriver (you need to have ChromeDriver installed and in your PATH)


def loop():
    global c_i
 
    
    food_country.append(driver.find_element(By.XPATH,'//*[@id="cmkt"]/div[5]/table/tbody/tr[' + str(c_i) + ']/td[8]/span').text)

    food_earning.append(driver.find_element(By.XPATH,'//*[@id="cmkt"]/div[5]/table/tbody/tr[' + str(c_i) + ']/td[4]').text)

        



# page iteration
for pg_id in range(3,4): 
    driver = webdriver.Chrome()

    url = f"https://companiesmarketcap.com/food/most-profitable-food-companies/?page={pg_id}"

    driver.get(url)        

    c_i = 1

    for i in range(1,40):

        r_iter=i
       
        cat='🍴 Food'
        food_category.append(cat)
        
        
        if pg_id == 1:
            rank=i
            
        elif pg_id == 2:
            rank=i+100
           
        elif pg_id == 3:
            rank=i+200
            
        elif pg_id == 4:
            rank=i+300   
            
        elif pg_id == 5:
            rank=i+400 
        
        elif pg_id == 6:
            rank=i+500 
         
        else:
            rank=i+600 
            

        if r_iter==18 or r_iter == 76:
            c_i +=1
            loop()

        else:
            loop()

        c_i+=1

    driver.close()

# %%
data = {'Category': food_category, 'Earning': food_earning,'Country': food_country}
food_rev=pd.DataFrame(data)
food_rev=food_rev[food_rev.Earning !='N/A']


food_rev
# Out:
#     Category   Earning      Country
# 0     🍴 Food  $12.21 B  Switzerland
# 1     🍴 Food  $10.34 B          USA
# 2     🍴 Food   $8.07 B           UK
# 3     🍴 Food   $5.50 B       France
# 4     🍴 Food   $5.48 B          USA
# ..       ...       ...          ...
# 234   🍴 Food   -$0.6 B        China
# 235   🍴 Food  -$0.87 B    Singapore
# 236   🍴 Food  -$1.06 B          USA
# 237   🍴 Food  -$2.87 B       France
# 238   🍴 Food  -$6.09 B  Netherlands
#
# [238 rows x 3 columns]

# %% [markdown]
# ### Auto

# %%
auto_country=[]
auto_category=[] 
auto_earning=[]

# Set up the Chrome WebDriver (you need to have ChromeDriver installed and in your PATH)
def loop():
    global c_i
    global company
 
    
    auto_country.append(driver.find_element(By.XPATH,'//*[@id="cmkt"]/div[5]/table/tbody/tr[' + str(c_i) + ']/td[8]/span').text)
    auto_earning.append(driver.find_element(By.XPATH,'//*[@id="cmkt"]/div[5]/table/tbody/tr[' + str(c_i) + ']/td[4]').text)

        



# page iteration
for pg_id in range(1,2): 
    driver = webdriver.Chrome()

    url = f"https://companiesmarketcap.com/automakers/most-profitable-automakers/"


    driver.get(url)        

    c_i = 1

    for i in range(1,61):

        r_iter=i
        
        cat='🚗 Automakers'
        auto_category.append(cat)
        
        if pg_id == 1:
            rank=i
            
        elif pg_id == 2:
            rank=i+100
           
        elif pg_id == 3:
            rank=i+200
            
        elif pg_id == 4:
            rank=i+300   
            
        elif pg_id == 5:
            rank=i+400 
        
        elif pg_id == 6:
            rank=i+500 
         
        else:
            rank=i+600 
            
            

        if r_iter==18 or r_iter == 76:
            c_i +=1
            loop()

        else:
            loop()

        c_i+=1

    driver.close()     
            

data = {'Category': auto_category, 'Earning': auto_earning,'Country': auto_country}
auto_earn=pd.DataFrame(data)
auto_earn


auto_earn=auto_earn[auto_earn.Earning !='N/A']

# %%
auto_earn
# Out:
#         Category    Earning      Country
# 0   🚗 Automakers   $38.55 B        Japan
# 1   🚗 Automakers   $29.05 B      Germany
# 2   🚗 Automakers   $24.51 B      Germany
# 3   🚗 Automakers   $23.01 B      Germany
# 4   🚗 Automakers   $18.95 B     S. Korea
# 5   🚗 Automakers   $15.20 B     S. Korea
# 6   🚗 Automakers   $15.09 B          USA
# 7   🚗 Automakers   $11.89 B          USA
# 8   🚗 Automakers   $11.85 B          USA
# 9   🚗 Automakers    $9.21 B        Japan
# 10  🚗 Automakers    $8.22 B      Germany
# 11  🚗 Automakers    $5.18 B        China
# 12  🚗 Automakers    $4.79 B        Japan
# 13  🚗 Automakers    $4.13 B        China
# 14  🚗 Automakers    $3.12 B        Japan
# 15  🚗 Automakers    $2.94 B        Japan
# 16  🚗 Automakers    $2.78 B  Netherlands
# 17  🚗 Automakers    $2.67 B        India
# 18  🚗 Automakers    $2.30 B       France
# 19  🚗 Automakers    $2.15 B        Japan
# 20  🚗 Automakers    $1.74 B       Sweden
# 21  🚗 Automakers    $1.71 B        Japan
# ...

# %% [markdown]
# ### Ecommerce

# %%
ecom_country=[]
ecom_category=[] 
ecom_earning=[]

# Set up the Chrome WebDriver (you need to have ChromeDriver installed and in your PATH)
def loop():
    global c_i
    global company
 
    
    
    ecom_country.append(driver.find_element(By.XPATH,'//*[@id="cmkt"]/div[5]/table/tbody/tr[' + str(c_i) + ']/td[8]/span').text)

    ecom_earning.append(driver.find_element(By.XPATH,'//*[@id="cmkt"]/div[5]/table/tbody/tr[' + str(c_i) + ']/td[4]').text)

        



# page iteration
for pg_id in range(1,2): 
    driver = webdriver.Chrome()

    url = f"https://companiesmarketcap.com/e-commerce/most-profitable-e-commerce-companies/"


    driver.get(url)        

    c_i = 1

    for i in range(1,96):

        r_iter=i
        
        cat='🛒 E-Commerce'
        ecom_category.append(cat)
        
        if pg_id == 1:
            rank=i
            
        elif pg_id == 2:
            rank=i+100
           
        elif pg_id == 3:
            rank=i+200
            
        elif pg_id == 4:
            rank=i+300   
            
        elif pg_id == 5:
            rank=i+400 
        
        elif pg_id == 6:
            rank=i+500 
         
        else:
            rank=i+600 
            

        if r_iter==18 or r_iter == 76:
            c_i +=1
            loop()

        else:
            loop()

        c_i+=1

    driver.close()     
            


data = {'Category': ecom_category, 'Earning': ecom_earning,'Country': ecom_country}
ecom_earn=pd.DataFrame(data)
ecom_earn


ecom_earn=ecom_earn[ecom_earn.Earning !='N/A']

# %%
ecom_earn
# Out:
#         Category   Earning    Country
# 0   🛒 E-Commerce  $26.07 B        USA
# 1   🛒 E-Commerce  $23.12 B      China
# 2   🛒 E-Commerce   $6.88 B      China
# 3   🛒 E-Commerce   $4.91 B      China
# 4   🛒 E-Commerce   $2.39 B        USA
# ..           ...       ...        ...
# 90  🛒 E-Commerce   -$0.9 B        USA
# 91  🛒 E-Commerce  -$1.12 B     Canada
# 92  🛒 E-Commerce  -$1.39 B      Japan
# 93  🛒 E-Commerce  -$1.68 B     Norway
# 94  🛒 E-Commerce   -$1.9 B  Indonesia
#
# [95 rows x 3 columns]

# %% [markdown]
# ### Restaurants

# %%
res_country=[]
res_category=[] 
res_earning=[]
# Set up the Chrome WebDriver (you need to have ChromeDriver installed and in your PATH)
def loop():
    global c_i
    global company
 
    
    res_country.append(driver.find_element(By.XPATH,'//*[@id="cmkt"]/div[5]/table/tbody/tr[' + str(c_i) + ']/td[8]/span').text)

    res_earning.append(driver.find_element(By.XPATH,'//*[@id="cmkt"]/div[5]/table/tbody/tr[' + str(c_i) + ']/td[4]').text)

        



# page iteration
for pg_id in range(1,2): 
    driver = webdriver.Chrome()

    url = f"https://companiesmarketcap.com/restaurant-chains/most-profitable-restaurant-chain-companies/"


    driver.get(url)        

    c_i = 1

    for i in range(1,56):

        r_iter=i
        
        cat='🍔 Restaurant chains'
        res_category.append(cat)
        
        if pg_id == 1:
            rank=i
            
        elif pg_id == 2:
            rank=i+100
           
        elif pg_id == 3:
            rank=i+200
            
        elif pg_id == 4:
            rank=i+300   
            
        elif pg_id == 5:
            rank=i+400 
        
        elif pg_id == 6:
            rank=i+500 
         
        else:
            rank=i+600 
        

        if r_iter==18 or r_iter == 76:
            c_i +=1
            loop()

        else:
            loop()

        c_i+=1

    driver.close()     
            


data = {'Category': res_category, 'Earning': res_earning,'Country': res_country}
res_earn=pd.DataFrame(data)



res_earn=res_earn[res_earn.Earning !='N/A']

# %%
res_earn
# Out:
#                Category    Earning      Country
# 0   🍔 Restaurant chains   $10.34 B          USA
# 1   🍔 Restaurant chains    $1.78 B          USA
# 2   🍔 Restaurant chains    $1.55 B          USA
# 3   🍔 Restaurant chains    $1.33 B       Canada
# 4   🍔 Restaurant chains    $1.20 B          USA
# 5   🍔 Restaurant chains    $1.16 B        China
# 6   🍔 Restaurant chains    $0.79 B          USA
# 7   🍔 Restaurant chains    $0.34 B          USA
# 8   🍔 Restaurant chains    $0.34 B          USA
# 9   🍔 Restaurant chains    $0.30 B        China
# 10  🍔 Restaurant chains    $0.30 B  Philippines
# 11  🍔 Restaurant chains    $0.29 B          USA
# 12  🍔 Restaurant chains    $0.28 B          USA
# 13  🍔 Restaurant chains    $0.28 B      Uruguay
# 14  🍔 Restaurant chains    $0.27 B          USA
# 15  🍔 Restaurant chains    $0.25 B        Japan
# 16  🍔 Restaurant chains    $0.18 B          USA
# 17  🍔 Restaurant chains    $0.16 B          USA
# 18  🍔 Restaurant chains    $0.14 B          USA
# ...

# %% [markdown]
# ## READ ALL Earning Files

# %%
all_earn=pd.read_csv('Earnings.csv')

# %%
all_earn
# Out:
#       Rank                        Company      Earnings
# 0        1              Johnson & Johnson  2.443000e+10
# 1        2                          Roche  1.767000e+10
# 2        3                     CVS Health  1.409000e+10
# 3        4                   Novo Nordisk  1.284000e+10
# 4        5                         Pfizer  1.225000e+10
# ...    ...                            ...           ...
# 1138    51                      Red Robin -5.079000e+07
# 1139    52       The Restaurant Group plc -1.100000e+08
# 1140    53  TH International (Tims China) -1.200000e+08
# 1141    54                     FAT Brands -1.200000e+08
# 1142    55                     Sweetgreen -1.600000e+08
#
# [1143 rows x 3 columns]

# %%
pharma_categories = pharma['Category'].tolist()
food_rev_categories = food_rev['Category'].tolist()
auto_earn_categories = auto_earn['Category'].tolist()
ecom_earn_categories = ecom_earn['Category'].tolist()
res_earn_categories = res_earn['Category'].tolist()

# %%
combined_categories = pharma_categories + food_rev_categories + auto_earn_categories + ecom_earn_categories + res_earn_categories

# %%
len(combined_categories)
# Out:
# 1143

# %%
all_earn['Category']=combined_categories

# %%
pharma = pharma['Country'].tolist()
food = food_rev['Country'].tolist()
auto = auto_earn['Country'].tolist()
ecom = ecom_earn['Country'].tolist()
res= res_earn['Country'].tolist()

# %%
combined_country = pharma + food + auto + ecom + res
all_earn['Country']=combined_country

# %%
all_earn.to_csv('Final_Earning.csv',index=False)
